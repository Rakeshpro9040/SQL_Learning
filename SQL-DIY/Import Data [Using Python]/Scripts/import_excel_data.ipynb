# %%
import pandas as pd

# %%
file = 'data-map.xlsx'

# %%
xl = pd.ExcelFile(file)
ls = list(xl.sheet_names)

# %%
ls[:3]
# Out:
# ['DMDUNIT', 'LOC', 'UDT_LOC_DMDGROUP']

# %%
ls[-3:]
# Out:
# ['IBP Calendar Outbound', 'DFU Outbound', 'DMDUNIT Outbound']

# %%
df = pd.read_excel(file, 'DMDUNIT', skiprows=2)

# %%
df.head(15)
# Out:
#                     COLUMN       Functional Name  \
# 0                  DMDUNIT               DMDUNIT
# 1                    DESCR                 DESCR
# 2           HIERARCHYLEVEL       HIERARCHY LEVEL
# 3   U_APPLICATION_CATEGORY  Application Category
# 4           U_ASPECT_RATIO          Aspect Ratio
# 5                  U_BRAND                 Brand
# 6             U_BRAND_ABBR    Brand Abbreviation
# 7         U_BRAND_GRP_TYPE      Brand Group Type
# 8      U_EXTENDED_DIVISION     Extended Division
# 9          U_CREATION_DATE         Creation Date
# 10         U_CROSS_SECTION         Cross Section
# 11             U_DISC_DATE      Discontinue date
# 12              U_DIVISION              Division
# 13           U_DMD_SEGMENT        Demand Segment
# 14  U_EXTENDED_DESCRIPTION                   NaN
#
#                                   BUSINESS DEFINITION Required (Yes/No)  \
# 0   A unique product that will be forecasted. All ...                 Y
# ...
